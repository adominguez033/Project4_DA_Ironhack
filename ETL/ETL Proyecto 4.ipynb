# %%
import requests as rq

from bs4 import BeautifulSoup as bs 

import pandas as pd

pd.set_option('display.max_rows', None)

# %%
url='https://es.wikipedia.org/wiki/MasterChef_Espa%C3%B1a'

# %%
html=rq.get(url).content
soup=bs(html, 'html.parser')

# %%
tabla=soup.find_all('table')[4]

# %%
filas=tabla.find_all('tr')

filas=[f.text.strip().split('\n') for f in filas]

filas[:5]
# Out:
# [['Nombre[26]\u200b', 'Procedencia', 'Edad', 'Ocupación', 'Información'],
#  ['Juan Manuel Sánchez',
#   '',
#   ' Almería',
#   '',
#   '26',
#   '',
#   'Camarero',
#   '',
#   'Ganador[27]\u200b'],
#  ['Eva M. Millán',
#   '',
#   ' Córdoba',
#   '',
#   '32',
#   '',
#   'Bióloga y nutricionista',
#   '',
#   '2.ª finalista[28]\u200b'],
#  ['Fabián León',
#   '',
#   ' Mallorca',
#   '',
#   '18',
#   '',
#   'Estudiante de Publicidad',
#   '',
#   '3.er finalista'],
#  ['José David Moliner',
#   '',
#   ' Valencia',
#   '',
#   '33',
#   '',
#   'Ingeniero informático',
#   '',
#   '13.er expulsado']]

# %%
final=[]

for f in filas:
    
    tmp=[]
    
    for palabra in f:
        
        if palabra!='':
            
            tmp.append(palabra)
            
    final.append(tmp)
    
final[:5]
# Out:
# [['Nombre[26]\u200b', 'Procedencia', 'Edad', 'Ocupación', 'Información'],
#  ['Juan Manuel Sánchez', ' Almería', '26', 'Camarero', 'Ganador[27]\u200b'],
#  ['Eva M. Millán',
#   ' Córdoba',
#   '32',
#   'Bióloga y nutricionista',
#   '2.ª finalista[28]\u200b'],
#  ['Fabián León',
#   ' Mallorca',
#   '18',
#   'Estudiante de Publicidad',
#   '3.er finalista'],
#  ['José David Moliner',
#   ' Valencia',
#   '33',
#   'Ingeniero informático',
#   '13.er expulsado']]

# %%
col_names=final[0]

data=final[1:]

edicion1=pd.DataFrame(data, columns=col_names)

# %%
edicion1.columns =['nombre', 'procedencia', 'edad', 'ocupacion', 'ranking']

# %%
edicion1['edicion']='1'
edicion1['sexo']='F'

# %%
edicion1.loc[0,'sexo'] = 'M'
edicion1.loc[1,'sexo'] = 'F'
edicion1.loc[2,'sexo'] = 'M'
edicion1.loc[3,'sexo'] = 'M'
edicion1.loc[4,'sexo'] = 'F'
edicion1.loc[5,'sexo'] = 'M'
edicion1.loc[6,'sexo'] = 'F'
edicion1.loc[7,'sexo'] = 'F'
edicion1.loc[8,'sexo'] = 'M'
edicion1.loc[9,'sexo'] = 'M'
edicion1.loc[10,'sexo'] = 'F'
edicion1.loc[11,'sexo'] = 'M'
edicion1.loc[12,'sexo'] = 'F'
edicion1.loc[13,'sexo'] = 'M'
edicion1.loc[14,'sexo'] = 'F'

# %%
edicion1.loc[0,'ranking'] = '1'
edicion1.loc[1,'ranking'] = '2'
edicion1.loc[2,'ranking'] = '3'
edicion1.loc[3,'ranking'] = '4'
edicion1.loc[4,'ranking'] = '5'
edicion1.loc[5,'ranking'] = '6'
edicion1.loc[6,'ranking'] = '7'
edicion1.loc[7,'ranking'] = '8'
edicion1.loc[8,'ranking'] = '9'
edicion1.loc[9,'ranking'] = '10'
edicion1.loc[10,'ranking'] = '11'
edicion1.loc[11,'ranking'] = '12'
edicion1.loc[12,'ranking'] = '13'
edicion1.loc[13,'ranking'] = '14'
edicion1.loc[14,'ranking'] = '15'

# %%
tabla=soup.find_all('table')[8]


filas=tabla.find_all('tr')

filas=[f.text.strip().split('\n') for f in filas]

filas[:5]


final=[]

for f in filas:
    
    tmp=[]
    
    for palabra in f:
        
        if palabra!='':
            
            tmp.append(palabra)
            
    final.append(tmp)
    
final[:5]


col_names=final[0]

data=final[1:]

edicion2=pd.DataFrame(data, columns=col_names)

# %%
edicion2.columns =['nombre', 'procedencia', 'edad', 'ocupacion', 'ranking']

# %%
edicion2['edicion']='2'
edicion2['sexo']='F'

# %%
edicion2.loc[0,'sexo'] = 'F'
edicion2.loc[1,'sexo'] = 'M'
edicion2.loc[2,'sexo'] = 'M'
edicion2.loc[3,'sexo'] = 'M'
edicion2.loc[4,'sexo'] = 'F'
edicion2.loc[5,'sexo'] = 'F'
edicion2.loc[6,'sexo'] = 'F'
edicion2.loc[7,'sexo'] = 'F'
edicion2.loc[8,'sexo'] = 'M'
edicion2.loc[9,'sexo'] = 'F'
edicion2.loc[10,'sexo'] = 'M'
edicion2.loc[11,'sexo'] = 'M'
edicion2.loc[12,'sexo'] = 'F'
edicion2.loc[13,'sexo'] = 'M'
edicion2.loc[14,'sexo'] = 'F'

# %%
edicion2.loc[0,'ranking'] = '1'
edicion2.loc[1,'ranking'] = '2'
edicion2.loc[2,'ranking'] = '3'
edicion2.loc[3,'ranking'] = '4'
edicion2.loc[4,'ranking'] = '5'
edicion2.loc[5,'ranking'] = '6'
edicion2.loc[6,'ranking'] = '7'
edicion2.loc[7,'ranking'] = '8'
edicion2.loc[8,'ranking'] = '9'
edicion2.loc[9,'ranking'] = '10'
edicion2.loc[10,'ranking'] = '11'
edicion2.loc[11,'ranking'] = '12'
edicion2.loc[12,'ranking'] = '13'
edicion2.loc[13,'ranking'] = '14'
edicion2.loc[14,'ranking'] = '15'

# %%
tabla=soup.find_all('table')[12]


filas=tabla.find_all('tr')

filas=[f.text.strip().split('\n') for f in filas]

filas[:5]


final=[]

for f in filas:
    
    tmp=[]
    
    for palabra in f:
        
        if palabra!='':
            
            tmp.append(palabra)
            
    final.append(tmp)
    
final[:5]


col_names=final[0]

data=final[1:]

edicion3=pd.DataFrame(data, columns=col_names)

# %%
edicion3.columns =['nombre', 'procedencia', 'edad', 'ocupacion', 'ranking']

# %%
edicion3['edicion']='3'
edicion3['sexo']='F'

# %%
edicion3.loc[0,'sexo'] = 'M'
edicion3.loc[1,'sexo'] = 'F'
edicion3.loc[2,'sexo'] = 'F'
edicion3.loc[3,'sexo'] = 'M'
edicion3.loc[4,'sexo'] = 'M'
edicion3.loc[5,'sexo'] = 'F'
edicion3.loc[6,'sexo'] = 'F'
edicion3.loc[7,'sexo'] = 'M'
edicion3.loc[8,'sexo'] = 'M'
edicion3.loc[9,'sexo'] = 'M'
edicion3.loc[10,'sexo'] = 'F'
edicion3.loc[11,'sexo'] = 'F'
edicion3.loc[12,'sexo'] = 'F'
edicion3.loc[13,'sexo'] = 'F'
edicion3.loc[14,'sexo'] = 'M'

# %%
edicion3.loc[0,'ranking'] = '1'
edicion3.loc[1,'ranking'] = '2'
edicion3.loc[2,'ranking'] = '3'
edicion3.loc[3,'ranking'] = '4'
edicion3.loc[4,'ranking'] = '5'
edicion3.loc[5,'ranking'] = '6'
edicion3.loc[6,'ranking'] = '7'
edicion3.loc[7,'ranking'] = '8'
edicion3.loc[8,'ranking'] = '9'
edicion3.loc[9,'ranking'] = '10'
edicion3.loc[10,'ranking'] = '11'
edicion3.loc[11,'ranking'] = '12'
edicion3.loc[12,'ranking'] = '13'
edicion3.loc[13,'ranking'] = '14'
edicion3.loc[14,'ranking'] = '15'

# %%
tabla=soup.find_all('table')[16]


filas=tabla.find_all('tr')

filas=[f.text.strip().split('\n') for f in filas]

filas[:5]


final=[]

for f in filas:
    
    tmp=[]
    
    for palabra in f:
        
        if palabra!='':
            
            tmp.append(palabra)
            
    final.append(tmp)
    
final[:5]


col_names=final[0]

data=final[1:]

edicion4=pd.DataFrame(data, columns=col_names)

# %%
edicion4.columns =['nombre', 'procedencia', 'edad', 'ocupacion', 'ranking']

# %%
edicion4['edicion']='4'
edicion4['sexo']='F'

# %%
edicion4.loc[0,'sexo'] = 'F'
edicion4.loc[1,'sexo'] = 'M'
edicion4.loc[2,'sexo'] = 'M'
edicion4.loc[3,'sexo'] = 'F'
edicion4.loc[4,'sexo'] = 'F'
edicion4.loc[5,'sexo'] = 'M'
edicion4.loc[6,'sexo'] = 'F'
edicion4.loc[7,'sexo'] = 'M'
edicion4.loc[8,'sexo'] = 'F'
edicion4.loc[9,'sexo'] = 'M'
edicion4.loc[10,'sexo'] = 'F'
edicion4.loc[11,'sexo'] = 'M'
edicion4.loc[12,'sexo'] = 'F'
edicion4.loc[13,'sexo'] = 'M'
edicion4.loc[14,'sexo'] = 'F'
edicion4.loc[15,'sexo'] = 'F'

# %%
edicion4.loc[0,'ranking'] = '1'
edicion4.loc[1,'ranking'] = '2'
edicion4.loc[2,'ranking'] = '3'
edicion4.loc[3,'ranking'] = '4'
edicion4.loc[4,'ranking'] = '5'
edicion4.loc[5,'ranking'] = '6'
edicion4.loc[6,'ranking'] = '7'
edicion4.loc[7,'ranking'] = '8'
edicion4.loc[8,'ranking'] = '9'
edicion4.loc[9,'ranking'] = '10'
edicion4.loc[10,'ranking'] = '11'
edicion4.loc[11,'ranking'] = '12'
edicion4.loc[12,'ranking'] = '13'
edicion4.loc[13,'ranking'] = '14'
edicion4.loc[14,'ranking'] = '15'
edicion4.loc[15,'ranking'] = '16'

# %%
tabla=soup.find_all('table')[20]


filas=tabla.find_all('tr')

filas=[f.text.strip().split('\n') for f in filas]

filas[:5]


final=[]

for f in filas:
    
    tmp=[]
    
    for palabra in f:
        
        if palabra!='':
            
            tmp.append(palabra)
            
    final.append(tmp)
    
final[:5]


col_names=final[0]

data=final[1:]

edicion5=pd.DataFrame(data, columns=col_names)

# %%
edicion5.columns =['nombre', 'procedencia', 'edad', 'ocupacion', 'ranking']

# %%
edicion5['edicion']='5'
edicion5['sexo']='F'

# %%
edicion5.loc[0,'sexo'] = 'M'
edicion5.loc[1,'sexo'] = 'M'
edicion5.loc[2,'sexo'] = 'F'
edicion5.loc[3,'sexo'] = 'F'
edicion5.loc[4,'sexo'] = 'F'
edicion5.loc[5,'sexo'] = 'F'
edicion5.loc[6,'sexo'] = 'M'
edicion5.loc[7,'sexo'] = 'M'
edicion5.loc[8,'sexo'] = 'F'
edicion5.loc[9,'sexo'] = 'M'
edicion5.loc[10,'sexo'] = 'F'
edicion5.loc[11,'sexo'] = 'M'
edicion5.loc[12,'sexo'] = 'F'
edicion5.loc[13,'sexo'] = 'M'
edicion5.loc[14,'sexo'] = 'F'
edicion5.loc[15,'sexo'] = 'M'

# %%
edicion5.loc[0,'ranking'] = '1'
edicion5.loc[1,'ranking'] = '2'
edicion5.loc[2,'ranking'] = '3'
edicion5.loc[3,'ranking'] = '4'
edicion5.loc[4,'ranking'] = '5'
edicion5.loc[5,'ranking'] = '6'
edicion5.loc[6,'ranking'] = '7'
edicion5.loc[7,'ranking'] = '8'
edicion5.loc[8,'ranking'] = '9'
edicion5.loc[9,'ranking'] = '10'
edicion5.loc[10,'ranking'] = '11'
edicion5.loc[11,'ranking'] = '12'
edicion5.loc[12,'ranking'] = '13'
edicion5.loc[13,'ranking'] = '14'
edicion5.loc[14,'ranking'] = '15'
edicion5.loc[15,'ranking'] = '16'

# %%
tabla=soup.find_all('table')[24]


filas=tabla.find_all('tr')

filas=[f.text.strip().split('\n') for f in filas]

filas[:5]


final=[]

for f in filas:
    
    tmp=[]
    
    for palabra in f:
        
        if palabra!='':
            
            tmp.append(palabra)
            
    final.append(tmp)
    
final[:5]


col_names=final[0]

data=final[1:]

edicion6=pd.DataFrame(data, columns=col_names)

# %%
edicion6.columns =['nombre', 'procedencia', 'edad', 'ocupacion', 'ranking']

# %%
edicion6['edicion']='6'
edicion6['sexo']='F'

# %%
edicion6.loc[0,'sexo'] = 'F'
edicion6.loc[1,'sexo'] = 'F'
edicion6.loc[2,'sexo'] = 'F'
edicion6.loc[3,'sexo'] = 'M'
edicion6.loc[4,'sexo'] = 'M'
edicion6.loc[5,'sexo'] = 'F'
edicion6.loc[6,'sexo'] = 'M'
edicion6.loc[7,'sexo'] = 'M'
edicion6.loc[8,'sexo'] = 'M'
edicion6.loc[9,'sexo'] = 'M'
edicion6.loc[10,'sexo'] = 'F'
edicion6.loc[11,'sexo'] = 'M'
edicion6.loc[12,'sexo'] = 'F'
edicion6.loc[13,'sexo'] = 'F'
edicion6.loc[14,'sexo'] = 'M'

# %%
edicion6.loc[0,'ranking'] = '1'
edicion6.loc[1,'ranking'] = '2'
edicion6.loc[2,'ranking'] = '3'
edicion6.loc[3,'ranking'] = '4'
edicion6.loc[4,'ranking'] = '5'
edicion6.loc[5,'ranking'] = '6'
edicion6.loc[6,'ranking'] = '7'
edicion6.loc[7,'ranking'] = '8'
edicion6.loc[8,'ranking'] = '9'
edicion6.loc[9,'ranking'] = '10'
edicion6.loc[10,'ranking'] = '11'
edicion6.loc[11,'ranking'] = '12'
edicion6.loc[12,'ranking'] = '13'
edicion6.loc[13,'ranking'] = '14'
edicion6.loc[14,'ranking'] = '15'

# %%
tabla=soup.find_all('table')[28]


filas=tabla.find_all('tr')

filas=[f.text.strip().split('\n') for f in filas]

filas[:5]


final=[]

for f in filas:
    
    tmp=[]
    
    for palabra in f:
        
        if palabra!='':
            
            tmp.append(palabra)
            
    final.append(tmp)
    
final[:5]


col_names=final[0]

data=final[1:]

edicion7=pd.DataFrame(data, columns=col_names)

# %%
edicion7.columns =['nombre', 'procedencia', 'edad', 'ocupacion', 'ranking']

# %%
edicion7['edicion']='7'
edicion7['sexo']='F'

# %%
edicion7.loc[0,'sexo'] = 'M'
edicion7.loc[1,'sexo'] = 'F'
edicion7.loc[2,'sexo'] = 'M'
edicion7.loc[3,'sexo'] = 'F'
edicion7.loc[4,'sexo'] = 'M'
edicion7.loc[5,'sexo'] = 'F'
edicion7.loc[6,'sexo'] = 'F'
edicion7.loc[7,'sexo'] = 'F'
edicion7.loc[8,'sexo'] = 'F'
edicion7.loc[9,'sexo'] = 'M'
edicion7.loc[10,'sexo'] = 'M'
edicion7.loc[11,'sexo'] = 'M'
edicion7.loc[12,'sexo'] = 'F'
edicion7.loc[13,'sexo'] = 'F'
edicion7.loc[14,'sexo'] = 'F'
edicion7.loc[15,'sexo'] = 'M'

# %%
edicion7.loc[0,'ranking'] = '1'
edicion7.loc[1,'ranking'] = '2'
edicion7.loc[2,'ranking'] = '3'
edicion7.loc[3,'ranking'] = '4'
edicion7.loc[4,'ranking'] = '5'
edicion7.loc[5,'ranking'] = '6'
edicion7.loc[6,'ranking'] = '7'
edicion7.loc[7,'ranking'] = '8'
edicion7.loc[8,'ranking'] = '9'
edicion7.loc[9,'ranking'] = '10'
edicion7.loc[10,'ranking'] = '11'
edicion7.loc[11,'ranking'] = '12'
edicion7.loc[12,'ranking'] = '13'
edicion7.loc[13,'ranking'] = '14'
edicion7.loc[14,'ranking'] = '15'
edicion7.loc[15,'ranking'] = '16'

# %%
tabla=soup.find_all('table')[32]


filas=tabla.find_all('tr')

filas=[f.text.strip().split('\n') for f in filas]

filas[:5]


final=[]

for f in filas:
    
    tmp=[]
    
    for palabra in f:
        
        if palabra!='':
            
            tmp.append(palabra)
            
    final.append(tmp)
    
final[:5]


col_names=final[0]

data=final[1:]

edicion8=pd.DataFrame(data, columns=col_names)

# %%
edicion8.columns =['nombre', 'procedencia', 'edad', 'ocupacion', 'ranking']

# %%
edicion8['edicion']='8'
edicion8['sexo']='F'

# %%
edicion8.loc[0,'sexo'] = 'F'
edicion8.loc[1,'sexo'] = 'M'
edicion8.loc[2,'sexo'] = 'M'
edicion8.loc[3,'sexo'] = 'M'
edicion8.loc[4,'sexo'] = 'F'
edicion8.loc[5,'sexo'] = 'M'
edicion8.loc[6,'sexo'] = 'F'
edicion8.loc[7,'sexo'] = 'M'
edicion8.loc[8,'sexo'] = 'F'
edicion8.loc[9,'sexo'] = 'M'
edicion8.loc[10,'sexo'] = 'F'
edicion8.loc[11,'sexo'] = 'F'
edicion8.loc[12,'sexo'] = 'M'
edicion8.loc[13,'sexo'] = 'F'
edicion8.loc[14,'sexo'] = 'F'
edicion8.loc[15,'sexo'] = 'F'
edicion8.loc[16,'sexo'] = 'F'
edicion8.loc[17,'sexo'] = 'M'

# %%
edicion8.loc[0,'ranking'] = '1'
edicion8.loc[1,'ranking'] = '2'
edicion8.loc[2,'ranking'] = '3'
edicion8.loc[3,'ranking'] = '4'
edicion8.loc[4,'ranking'] = '5'
edicion8.loc[5,'ranking'] = '6'
edicion8.loc[6,'ranking'] = '7'
edicion8.loc[7,'ranking'] = '8'
edicion8.loc[8,'ranking'] = '9'
edicion8.loc[9,'ranking'] = '10'
edicion8.loc[10,'ranking'] = '11'
edicion8.loc[11,'ranking'] = '12'
edicion8.loc[12,'ranking'] = '13'
edicion8.loc[13,'ranking'] = '14'
edicion8.loc[14,'ranking'] = '15'
edicion8.loc[15,'ranking'] = '16'
edicion8.loc[16,'ranking'] = '17'
edicion8.loc[17,'ranking'] = '18'

# %%
tabla=soup.find_all('table')[36]


filas=tabla.find_all('tr')

filas=[f.text.strip().split('\n') for f in filas]

filas[:5]


final=[]

for f in filas:
    
    tmp=[]
    
    for palabra in f:
        
        if palabra!='':
            
            tmp.append(palabra)
            
    final.append(tmp)
    
final[:5]


col_names=final[0]

data=final[1:]

edicion9=pd.DataFrame(data, columns=col_names)

# %%
edicion9.columns =['nombre', 'procedencia', 'edad', 'ocupacion', 'ranking']

# %%
edicion9['edicion']='9'
edicion9['sexo']='F'

# %%
edicion8.loc[0,'sexo'] = 'M'
edicion8.loc[1,'sexo'] = 'F'
edicion8.loc[2,'sexo'] = 'F'
edicion8.loc[3,'sexo'] = 'M'
edicion8.loc[4,'sexo'] = 'F'
edicion8.loc[5,'sexo'] = 'M'
edicion8.loc[6,'sexo'] = 'M'
edicion8.loc[7,'sexo'] = 'F'
edicion8.loc[8,'sexo'] = 'F'
edicion8.loc[9,'sexo'] = 'M'
edicion8.loc[10,'sexo'] = 'M'
edicion8.loc[11,'sexo'] = 'F'
edicion8.loc[12,'sexo'] = 'F'
edicion8.loc[13,'sexo'] = 'M'
edicion8.loc[14,'sexo'] = 'M'
edicion8.loc[15,'sexo'] = 'M'

# %%
edicion9.loc[0,'ranking'] = '1'
edicion9.loc[1,'ranking'] = '2'
edicion9.loc[2,'ranking'] = '3'
edicion9.loc[3,'ranking'] = '4'
edicion9.loc[4,'ranking'] = '5'
edicion9.loc[5,'ranking'] = '6'
edicion9.loc[6,'ranking'] = '7'
edicion9.loc[7,'ranking'] = '8'
edicion9.loc[8,'ranking'] = '9'
edicion9.loc[9,'ranking'] = '10'
edicion9.loc[10,'ranking'] = '11'
edicion9.loc[11,'ranking'] = '12'
edicion9.loc[12,'ranking'] = '13'
edicion9.loc[13,'ranking'] = '14'
edicion9.loc[14,'ranking'] = '15'
edicion9.loc[15,'ranking'] = '16'

# %%
todas_ediciones=pd.concat([edicion1, edicion2, edicion3, edicion4, edicion5, edicion6, edicion7, edicion8, edicion9], axis=0)

# %%
todas_ediciones.head()
# Out:
#                 nombre procedencia edad                 ocupacion ranking  \
# 0  Juan Manuel Sánchez     Almería   26                  Camarero       1
# 1        Eva M. Millán     Córdoba   32   Bióloga y nutricionista       2
# 2          Fabián León    Mallorca   18  Estudiante de Publicidad       3
# 3   José David Moliner    Valencia   33     Ingeniero informático       4
# 4          Maribel Gil   Castellón   59               Ama de casa       5
#
#   edicion sexo
# 0       1    M
# 1       1    F
# 2       1    M
# 3       1    M
# 4       1    F

# %%
todas_ediciones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 142 entries, 0 to 15
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   nombre       142 non-null    object
#  1   procedencia  142 non-null    object
#  2   edad         142 non-null    object
#  3   ocupacion    142 non-null    object
#  4   ranking      142 non-null    object
#  5   edicion      142 non-null    object
#  6   sexo         142 non-null    object
# dtypes: object(7)
# memory usage: 8.9+ KB

# %%
todas_ediciones['edad'] = todas_ediciones['edad'].astype('int')
todas_ediciones['ranking'] = todas_ediciones['ranking'].astype('int')
todas_ediciones['edicion'] = todas_ediciones['edicion'].astype('int')

# %%
todas_ediciones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 142 entries, 0 to 15
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   nombre       142 non-null    object
#  1   procedencia  142 non-null    object
#  2   edad         142 non-null    int32
#  3   ocupacion    142 non-null    object
#  4   ranking      142 non-null    int32
#  5   edicion      142 non-null    int32
#  6   sexo         142 non-null    object
# dtypes: int32(3), object(4)
# memory usage: 7.2+ KB

# %%
todas_ediciones = todas_ediciones.reset_index()
todas_ediciones.head()
# Out:
#    index               nombre procedencia  edad                 ocupacion  \
# 0      0  Juan Manuel Sánchez     Almería    26                  Camarero
# 1      1        Eva M. Millán     Córdoba    32   Bióloga y nutricionista
# 2      2          Fabián León    Mallorca    18  Estudiante de Publicidad
# 3      3   José David Moliner    Valencia    33     Ingeniero informático
# 4      4          Maribel Gil   Castellón    59               Ama de casa
#
#    ranking  edicion sexo
# 0        1        1    M
# 1        2        1    F
# 2        3        1    M
# 3        4        1    M
# 4        5        1    F

# %%
todas_ediciones.drop('index', inplace=True, axis=1)

# %%
todas_ediciones.head()
# Out:
#                 nombre procedencia  edad                 ocupacion  ranking  \
# 0  Juan Manuel Sánchez     Almería    26                  Camarero        1
# 1        Eva M. Millán     Córdoba    32   Bióloga y nutricionista        2
# 2          Fabián León    Mallorca    18  Estudiante de Publicidad        3
# 3   José David Moliner    Valencia    33     Ingeniero informático        4
# 4          Maribel Gil   Castellón    59               Ama de casa        5
#
#    edicion sexo
# 0        1    M
# 1        1    F
# 2        1    M
# 3        1    M
# 4        1    F

# %%
todas_ediciones['ocupacion2']=todas_ediciones['ocupacion']

# %%
ocupacion2_list = todas_ediciones['ocupacion2'].tolist()

# %%
todas_ediciones.ocupacion2.replace(['Camarero',
 'Bióloga y nutricionista',
 'Estudiante de Publicidad',
 'Ingeniero informático',
 'Ama de casa',
 'Soldador',
 'Estudiante de Economía',
 'Maquilladora y esteticista',
 'Policía Foral',
 'Administrador de ingresos',
 'Ama de casa',
 'Estudiante de CAF',
 'Asistente administrativo',
 'Ingeniero de Telecomunicaciones',
 'Estudiante de Derecho',
 'Carnicera en paro',
 'Estudiante de Historia del Arte',
 'Camarero',
 'Realizador de publicidad',
 'Ingeniera de sonido y DJ',
 'Empresaria',
 'Dependienta',
 'Ex asistente de dirección',
 'Profesor de Yoga',
 'Técnico de radioterapia',
 'Doctor en Biología molecular',
 'Oficial funerario',
 'Ama de casa',
 'Arquitecto',
 'Estudiante de Ciencias Ambientales',
 'Vendedor ambulante',
 'Auxiliar de óptica',
 'Estudiante de Odontología y modelo',
 'Técnico de laboratorio',
 'Camarero y modelo',
 'Nutricionista',
 'Empresaria de calzado',
 'Camarero',
 'Campeón y maestro de artes marciales',
 'Empresario de ambientadores',
 'Voluntaria de ONG',
 'Jubilada',
 'Protésico dental',
 'Profesora de infantil',
 'Estudiante de Medicina',
 'Ama de casa',
 'Friegaplatos',
 'Pintor industrial',
 'Empresaria',
 'Ama de casa',
 'Estudiante de CAFD',
 'Modelo y periodista',
 'Ingeniero de estructuras',
 'Camarera',
 'Empresario',
 'Teleoperadora',
 'Estudiante de Enfermería',
 'Desempleada',
 'Auxiliar administrativo',
 'Ama de casa',
 'Profesora y atleta',
 'Exfutbolista profesional',
 'Jefe de sala',
 'Jubilada',
 'Policía Nacional',
 'Bloguera',
 'Panadera',
 'Diseñador de moda',
 'Banderillero',
 'Modelo profesional',
 'Emprendedor de negocios',
 'Abogada',
 'Camarero',
 'Peluquera y maquilladora',
 'Peluquero',
 'Psicóloga',
 'Delegado comercial',
 'Estudiante de Nutrición',
 'Dietista',
 'Empleada de hogar',
 'Community manager',
 'Bombero',
 'Estudiante de Turismo',
 'Ingeniero de telecomunicaciones',
 'Hostelero',
 'Financiero',
 'Periodista',
 'Comerciante',
 'Conductor de autobuses',
 'Comercial',
 'Jubilada',
 'Bodeguero',
 'Pescadero',
 'Fotógrafa',
 'Emprendedor',
 'Recursos Humanos',
 'Empresario',
 'Ama de casa',
 'Dependienta',
 'Diseñadora de lápidas',
 'Empleada del hogar',
 'Cerrajero forense',
 'Camarero',
 'Economista jubilado',
 'Ama de casa',
 'Comercial de informática',
 'Ingeniera mecánica',
 'Estadístico',
 'Empresaria de joyas',
 'Abogado',
 'Entrenador personal',
 'Exjugador y entrenador de fútbol sala',
 'Profesora de yoga',
 'Empresario y músico',
 'Conserje de comunidad de vecinos',
 'Profesor de Inglés',
 'Economista',
 'Comercial de tabaco',
 'Directora de tienda nupcial',
 'Farmacéutica',
 'Músico',
 'Educadora social',
 'Comandante del Ejército del Aire',
 'Limpiadora y camarera',
 'Directora de Marketing',
 'Empleado de tanatorio',
 'Comercial de grifos',
 'Fisioterapeuta y estudiante de Medicina',
 'Coordinadora de eventos',
 'Camarero',
 'Emprendedora de marketing hípico',
 'Cardiólogo',
 'Jugador profesional de póquer',
 'Estudiante de Farmacia y Nutrición',
 'Responsable de desarrollo de negocio',
 'Empresario hostelero',
 'Músico',
 'Directora de marketing y publicidad',
 'Guardia Civil',
 'Gestor deportivo',
 'Estudiante de Restauración',
 'Abogado jubilado'],
                                   
                                   
                                   
                                   

['Hostelería',
 'Salud',
 'Estudiante',
 'Ingeniería',
 'Ama/o de casa',
 'Oficio manual',
 'Estudiante',
 'Belleza',
 'Defensa',
 'Administrativo/a',
 'Ama/o de casa',
 'Estudiante',
 'Administrativo/a',
 'Ingeniería',
 'Estudiante',
 'Oficio alimentación',
 'Estudiante',
 'Hostelería',
 'Publicidad y márqueting',
 'Ingeniería',
 'Empresario/a',
 'Moda',
 'Administrativo/a',
 'Yoga o artes marciales',
 'Salud',
 'Salud',
 'Tanatorio',
 'Ama/o de casa',
 'Arquitectura',
 'Estudiante',
 'Vendedor ambulante',
 'Salud',
 'Estudiante',
 'Salud',
 'Hostelería',
 'Salud',
 'Empresario/a',
 'Hostelería',
 'Yoga o artes marciales',
 'Empresario/a',
 'Social',
 'Jubilado/a',
 'Salud',
 'Profesor/a',
 'Estudiante',
 'Ama/o de casa',
 'Hostelería',
 'Oficio manual',
 'Empresario/a',
 'Ama/o de casa',
 'Estudiante',
 'Periodista',
 'Ingeniería',
 'Hostelería',
 'Empresario/a',
 'Comercial',
 'Estudiante',
 'Paro',
 'Administrativo/a',
 'Ama/o de casa',
 'Profesor/a',
 'Deporte',
 'Hostelería',
 'Jubilado/a',
 'Defensa',
 'Influencer',
 'Oficio alimentación',
 'Diseñador/a',
 'Banderillero',
 'Modelo',
 'Empresario/a',
 'Abogacía',
 'Hostelería',
 'Belleza',
 'Belleza',
 'Psicología',
 'Comercial',
 'Estudiante',
 'Salud',
 'Empleada de hogar',
 'Community manager',
 'Defensa',
 'Estudiante',
 'Ingeniería',
 'Hostelería',
 'Finanzas',
 'Periodista',
 'Comercial',
 'Oficio manual',
 'Comercial',
 'Jubilado/a',
 'Influencer',
 'Oficio alimentación',
 'Fotografía',
 'Empresario/a',
 'RRHH',
 'Empresario/a',
 'Amo/a de casa',
 'Moda',
 'Diseñador/a',
 'Empleada del hogar',
 'Oficio manual',
 'Hostelería',
 'Jubilado/a',
 'Ama/o de casa',
 'Comercial',
 'Ingeniería',
 'Estadístico',
 'Empresario/a',
 'Abogacía',
 'Deporte',
 'Deporte',
 'Yoga o artes marciales',
 'Empresario/a',
 'Conserje',
 'Profesor/a',
 'Economista',
 'Comercial',
 'Moda',
 'Salud',
 'Música',
 'Social',
 'Defensa',
 'Hostelería',
 'Publicidad y márqueting',
 'Tanatorio',
 'Comercial',
 'Salud',
 'Eventos',
 'Hostelería',
 'Emprendedor/a',
 'Salud',
 'Póquer',
 'Estudiante',
 'Negocio',
 'Empresario/a',
 'Música',
 'Publicidad y márqueting',
 'Defensa',
 'Deporte',
 'Estudiante',
 'Jubilado/a'],inplace=True)

# %%
todas_ediciones.ocupacion2.unique()
# Out:
# array(['Hostelería', 'Salud', 'Estudiante', 'Ingeniería', 'Ama/o de casa',
#        'Oficio manual', 'Belleza', 'Defensa', 'Administrativo/a',
#        'Oficio alimentación', 'Publicidad y márqueting', 'Empresario/a',
#        'Moda', 'Yoga o artes marciales', 'Tanatorio', 'Arquitectura',
#        'Vendedor ambulante', 'Social', 'Jubilado/a', 'Profesor/a',
#        'Periodista', 'Comercial', 'Paro', 'Deporte', 'Influencer',
#        'Diseñador/a', 'Banderillero', 'Modelo', 'Abogacía', 'Psicología',
#        'Empleada de hogar', 'Community manager', 'Finanzas', 'Fotografía',
#        'RRHH', 'Empleada del hogar', 'Estadístico', 'Conserje',
#        'Economista', 'Música', 'Eventos', 'Emprendedor/a', 'Póquer',
#        'Negocio'], dtype=object)

# %%
todas_ediciones.head()
# Out:
#                 nombre procedencia  edad                 ocupacion  ranking  \
# 0  Juan Manuel Sánchez     Almería    26                  Camarero        1
# 1        Eva M. Millán     Córdoba    32   Bióloga y nutricionista        2
# 2          Fabián León    Mallorca    18  Estudiante de Publicidad        3
# 3   José David Moliner    Valencia    33     Ingeniero informático        4
# 4          Maribel Gil   Castellón    59               Ama de casa        5
#
#    edicion sexo     ocupacion2
# 0        1    M     Hostelería
# 1        1    F          Salud
# 2        1    M     Estudiante
# 3        1    M     Ingeniería
# 4        1    F  Ama/o de casa

# %%
todas_ediciones.to_excel(r'C:\Users\alexd\Ironhack\Proyectos\Project4_DA_Ironhack\Data\masterchef.xls', index=False)
# Out:
# C:\Users\alexd\AppData\Local\Temp/ipykernel_14416/3048578067.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   todas_ediciones.to_excel(r'C:\Users\alexd\Ironhack\Proyectos\Project4_DA_Ironhack\Data\masterchef.xls', index=False)

# %%
todas_ediciones.to_csv(r'C:\Users\alexd\Ironhack\Proyectos\Project4_DA_Ironhack\Data\masterchef.csv', index=False)

# %%
from sqlalchemy import create_engine

# %%
str_conn='mysql+pymysql://root:password@127.0.0.1:3306/project4'

cursor=create_engine(str_conn)

# %%
todas_ediciones.to_sql(name='masterchef', con=cursor, if_exists='replace', index=False)

# %%
info1=pd.read_clipboard()

# %%
info1
# Out:
#     PD       PEX     PEL   PI PEX.1 PEL.1  PI.1 PEX.2 PEL.2  PI.2  ...  1​.1  \
# 0    1      Juan  Manuel  ENT    EP    MD    MD    EP    MD   SMD  ...    GD
# 1    2       Eva     ENT   EP    MD   SMD    EP    IN    GD    EG  ...    AD
# 2    3    Fabián     ENT   EG    IN    BD    EP    MD    MD    EG  ...    BD
# 3    4      José   David  ENT    EP    GD    AD    EP   SPD    AD  ...    MD
# 4    5   Maribel     ENT   EP    BD    MD    EG    IN    MD    EP  ...    AD
# 5    6    Cerezo     ENT   EG    IN    MD    EP    GD    MD    EP  ...    BD
# 6    7     Clara     ENT   EG    IN    GD    EP    IN    MD    EG  ...  None
# 7    8     María     ENT   EG    IN    MD    EP    IN    BD    EP  ...  None
# 8    9      José    Luis  ENT    EP    MD    MD    EG    IN    MD  ...  None
# 9   10       Noé     ENT   EP    MD    MD    EP    MD    BD    EP  ...  None
# 10  11  Santiaga     ENT   EG    IN    BD    EG    IN    MD    EP  ...  None
# ...

# %%
info1['edicion']='1'
info1=info1.rename(columns = {'PD':'ranking'})

# %%
info2=pd.read_clipboard()

# %%
info2
# Out:
#     PD         PI    PEX  PEL PI.1 PEX.1 PEL.1  PI.2 PEX.2 PEL.2  ... PEX.9  \
# 0    1      Vicky    ENT   MD   EP    MD    GD    EP    MD   SMD  ...    GD
# 1    2      Mateo    ENT   MD   EP    AD    MD    EP    MD    GD  ...   SMD
# 2    3  Cristóbal    ENT   BD   EP    IN    MD    EP   SPD    MD  ...    BD
# 3    4       Emil    ENT   GD   EP    IN    MD    EP    BD    AD  ...    AD
# 4    5     Lorena    ENT   MD   EP   SPD   SMD    EP    MD    MD  ...  None
# 5    6   Cristina    ENT   AD   EP    IN    MD    EP    BD    MD  ...    BD
# 6    7  Milagrosa    ENT  SMD   EP    AD    BD    EP    MD    MD  ...  None
# 7    8     Marina    ENT   MD   EP    IN    BD    EP    BD    MD  ...  None
# 8    9    Gonzalo    ENT   MD   EP    IN    BD    EP    MD    MD  ...  None
# 9   10      Celia    ENT   MD   EP    AD    MD    EP    BD    MD  ...  None
# 10  11      Jorge    ENT   MD   EP    IN    MD    EP    MD    MD  ...  None
# ...

# %%
info2['edicion']='2'
info2=info2.rename(columns = {'PD':'ranking'})

# %%
info3=pd.read_clipboard()

# %%
info3
# Out:
#          PD   PI  PEX PEL PI.1 PEX.1 PEL.1  PI.2 PEX.2 PEL.2  ... PEL.8  PI.9  \
# 1    Carlos  ENT   GD  EG   IN    AD    EG    IN    GD    EG  ...    AD    MD
# 2     Sally  ENT   MD  EP   MD    GD    EP    AD    MD    EP  ...    MD    AD
# 3    Andrea  ENT   AD  EP   BD    MD    EP    MD   SMD    EP  ...    MD    AD
# 4   Antonio  ENT   MD  EG   IN    MD    EP    BD    MD    EG  ...    MD    MD
# 5     Kevin  ENT   MD  EG   IN    BD    EG    IN    AD    EG  ...   SPD    DD
# 6     Lidia  ENT   MD  EP   BD    MD    EG    IN    MD    EG  ...    AD    AD
# 7      Mila  ENT   MD  EG   IN    MD    EP    AD    MD    EP  ...  None  None
# 8     Fidel  ENT   MD  EG   IN    MD    EP    MD    MD    EG  ...    EL  None
# 9     Pablo  ENT  SMD  EP   MD    BD    EP    BD    MD    EP  ...  None  None
# 10   Víctor  ENT   MD  EG   IN   SMD    EG    IN    MD    EG  ...  None  None
# 11   Mireia  ENT   AD  EP   BD    MD    EG    IN    MD    EP  ...  None  None
# ...

# %%
info3['edicion']='3'

# %%
info3
# Out:
#          PD   PI  PEX PEL PI.1 PEX.1 PEL.1  PI.2 PEX.2 PEL.2  ...  PI.9 PEX.8  \
# 1    Carlos  ENT   GD  EG   IN    AD    EG    IN    GD    EG  ...    MD    EG
# 2     Sally  ENT   MD  EP   MD    GD    EP    AD    MD    EP  ...    AD    EG
# 3    Andrea  ENT   AD  EP   BD    MD    EP    MD   SMD    EP  ...    AD    EP
# 4   Antonio  ENT   MD  EG   IN    MD    EP    BD    MD    EG  ...    MD    EP
# 5     Kevin  ENT   MD  EG   IN    BD    EG    IN    AD    EG  ...    DD    NP
# 6     Lidia  ENT   MD  EP   BD    MD    EG    IN    MD    EG  ...    AD    EP
# 7      Mila  ENT   MD  EG   IN    MD    EP    AD    MD    EP  ...  None  None
# 8     Fidel  ENT   MD  EG   IN    MD    EP    MD    MD    EG  ...  None  None
# 9     Pablo  ENT  SMD  EP   MD    BD    EP    BD    MD    EP  ...  None  None
# 10   Víctor  ENT   MD  EG   IN   SMD    EG    IN    MD    EG  ...  None  None
# 11   Mireia  ENT   AD  EP   BD    MD    EG    IN    MD    EP  ...  None  None
# ...

# %%
info4=pd.read_clipboard()

# %%
info4
# Out:
#                     PD  PI  PEX  PEL  PI.1 PEX.1 PEL.1  PI.2 PEX.2 PEL.2  ...  \
# 1  Virginia  ENT    MD  EP   MD   MD    EG    IN    MD    NP    EG    IN  ...
# 2  Ángel     ENT    MD  EG   IN   MD    EP    BD    MD    NP    EP    BD  ...
# 3  José      Luis  ENT  MD   EP   MD    MD    EG    IN    AD    MD    EP  ...
# 4  Rocío     ENT    BD  EP   MD   MD    EG    IN    AD    GD    EG    IN  ...
# 5  Raquel    ENT    AD  EP   IN   MD    EG    IN    MD    NP    EP    AD  ...
# 6  David     ENT    GD  EG   IN   MD    EP    MD    MD    NP    EG    IN  ...
# 7  Natalia   ENT    MD  EG   IN   AD    EP    AD    MD    NP    EG    IN  ...
# 8  Pablo     ENT    BD  EG   IN   MD    EP    AD    AD    MD    EG    IN  ...
# 9  Reichel   ENT    MD  EG   IN  PIN    EP    IN    MD    NP    EP    AD  ...
# 10 Daniel    ENT    MD  EP   MD   MD    EG    IN    AD   SMD    EP    IN  ...
# 11 Dania     EL     EG  IN   MD   NP    EG    IN    DG    BD    MD    EP  ...
# ...

# %%
info4['edicion']='4'
info4=info4.rename(columns = {'PD':'ranking'})

# %%
info5=pd.read_clipboard()

# %%
info5
# Out:
#           PD PEX PEL  PI PEX.1 PEL.1 PI.1 PEX.2 PEL.2 PI.2  ... PEX.10 PEL.10  \
# 1 Jorge  ENT  EG  IN  MD    EG    IN  SMD    EP    BD   MD  ...     AD    SMD
#
#         PI.10 PEX.11    n  1​ PEL.11 PI.11 PEX.12       CF
# 1 Jorge    EG     IN  SMD  GD     IN    GD     IN  GANADOR
#
# [1 rows x 41 columns]

# %%
info5['edicion']='5'
info5=info5.rename(columns = {'PD':'ranking'})

# %%
info6=pd.read_clipboard()

# %%
info6
# Out:
#                            PD   PEX   PEL    PI PEX.1 PEL.1  PI.1 PEX.2 PEL.2  \
# 1  Marta    ENT EP BD GD   AD    EG    IN    AD    EP    MD    AD    EP    EG
# 2  Ketty    ENT EG IN SMD  EG    IN    AD    EP    IN    GD    EP    EG    IN
# 3  Oxana    ENT EP AD IN   MD    EP    AD   SMD    EG    IN    BD    EP    EG
# 4  Toni     ENT EP AD IN   MD    EG    IN    BD    EG    IN    MD    EP    EG
# 5  Daniel   ENT EP AD IN   AD    EP    BD    MD    EP    MD    MD    EP    IN
# 6  Sofía    ENT EG IN BD   EG    IN    MD    EG    IN    MD    EP    IN    MD
# 7  Víctor   ENT EP AD IN   BD    EP    BD    GD    EP    GD    MD    EP    EG
# 8  Jon      ENT EP BD SPD  BD    EP    BD    AD    EG    IN    BD    EP    EP
# 9  Fabio    ENT EP AD IN   MD    EP    AD    MD    EG    IN    AD    EP    IN
# 10 Jorge    ENT EG IN BD   EG    IN    MD    EP   SPD    MD    EP    EP    AD
# 11 Marina   ENT EG IN MD   EG    IN    MD    EP    IN    BD    EP    EG    IN
# ...

# %%
info6['edicion']='6'
info6=info6.rename(columns = {'PD':'ranking'})

# %%
info7=pd.read_clipboard()

# %%
info7
# Out:
#                                           PD   PEX   PEL    PI PEX.1 PEL.1  \
# 1  Aleix    JC  ENT EP  AD BD  EP  MD     MD    EP    NP   SMD    IN    BD
# 2  Teresa   SVN ENT EP  MD MD  EG  IN     MD    EP    GD    IN    MD    EP
# 3  Valentín JC  ENT EP  BD MD  EP  AD     MD    EG    IN   SMD    EG    IN
# 4  Aitana   JC  ENT EP  IN MD  EG  IN     NP    IN    MD    EG    IN    MD
# 5  Carlos   SVN ENT EP  AD BD  EG  IN     MD    EP    IN    BD    EP    GD
# 6  Samira   PR  EL  ENT EG IN  MD  EP     MD    AD    GD    GD    EG    IN
# 7  Carmen   SVN ENT EP  BD SMD EP  MD     MD    EG    IN    MD    EG    IN
# 8  Natalia  PR  ENT EG  IN MD  EG  IN     MD    EG    IN    BD    EP    NP
# 9  Gloria   JC  ENT EP  MD MD  EP  AD     MD    EG    IN    MD    EP    IN
# 10 Marcos   JC  ENT EP  AD MD  EP  IN     MD    EP    BD    NP    GD    BD
# 11 Osiris   PR  ENT EG  IN GD  EG  AD     MD    EG    NP    GD    IN    BD
# ...

# %%
info7['edicion']='7'
info7=info7.rename(columns = {'PD':'ranking'})

# %%
info8=pd.read_clipboard()

# %%
info8
# Out:
#            PD  PEX PEL  PI PEX.1 PEL.1 PI.1 PEX.2 PEL.2 PI.2  ... PI.9 PEX.10  \
# 1 Ana MD  ENT  SMD  AD  IN    AD    EG   IN   SMD    EG   IN  ...   EP     GD
#
#          PEL.9 PI.10 PEXn  2​ PEL.10 PI.11 PEX.11        CF
# 1 Ana MD    IN    GD   EG  IN     GD    BD     IN  GANADORA
#
# [1 rows x 41 columns]

# %%
info8['edicion']='8'
info8=info8.rename(columns = {'PD':'ranking'})

# %%
info9=pd.read_clipboard()

# %%
info9
# Out:
#                                    PD   PEX   PEL    PI PEX.1 PEL.1  PI.1  \
# 1  Arnau      ENT   EP  BD  MD     EP    IN    GD    EP    MD    AD    IN
# 2  Meri       ENT   EG  IN  SMD    EG    IN    AD    EG    IN    MD    NP
# 3  María      ENT   EP  SMD GD     EP    GD    MD    EP    MD    MD   SPD
# 4  Fran       ENT   EG  IN  MD     EG    IN    BD    EG    IN    MD    NP
# 5  Ofelia     ENT   EP  MD  MD     EP    MD    MD    EP    AD    IN   SMD
# 6  José       AB    ENT SMD EP     NP    AD    IN    MD    EG    IN    BD
# 7  Toni       ENT   EP  IN  MD     EP    BD    BD    EG    IN    MD    NP
# 8  Amelicious ENT   EP  GD  AD     EG    IN   SMD    EG    IN    MD    NP
# 9  Jiaping    ENT   EG  IN  MD     EP    BD    AD    EG    IN    MD    NP
# 10 Dani       ENT   EG  IN  MD     EG    IN    AD    EP    AD    IN    MD
# 11 Pepe       ENT   EG  IN  MD     EG    IN    MD    EG    IN    MD    NP
# 12 Alicia     ENT   EG  IN  MD     EP    MD    MD    EG    IN    MD    NP
# ...

# %%
info9['edicion']='9'
info9=info9.rename(columns = {'PD':'ranking'})

# %%
todas_infos=pd.concat([info1, info2, info3, info4, info5, info6, info7, info8, info9], axis=0)

# %%
todas_infos
# Out:
#                                               ranking       PEX     PEL  \
# 0                                                   1      Juan  Manuel
# 1                                                   2       Eva     ENT
# 2                                                   3    Fabián     ENT
# 3                                                   4      José   David
# 4                                                   5   Maribel     ENT
# 5                                                   6    Cerezo     ENT
# 6                                                   7     Clara     ENT
# 7                                                   8     María     ENT
# 8                                                   9      José    Luis
# 9                                                  10       Noé     ENT
# 10                                                 11  Santiaga     ENT
# 11                                                 12     Efrén     ENT
# ...

# %%
todas_infos.to_excel(r'C:\Users\alexd\Ironhack\Proyectos\Project4_DA_Ironhack\Data\masterchef_info.xls', index=True)
# Out:
# C:\Users\alexd\AppData\Local\Temp/ipykernel_14416/3214401319.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   todas_infos.to_excel(r'C:\Users\alexd\Ironhack\Proyectos\Project4_DA_Ironhack\Data\masterchef_info.xls', index=True)

# %%
masterchef_info=pd.read_excel(r'C:\Users\alexd\Ironhack\Proyectos\Project4_DA_Ironhack\Data\masterchef_info.xls')

# %%
masterchef_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   edicion  110 non-null    int64
#  1   ranking  110 non-null    int64
#  2   EG       110 non-null    int64
#  3   EP       110 non-null    int64
# dtypes: int64(4)
# memory usage: 3.6 KB

# %%
str_conn='mysql+pymysql://root:password@127.0.0.1:3306/project4'

cursor=create_engine(str_conn)

# %%
masterchef_info.to_sql(name='info', con=cursor, if_exists='replace', index=False)
